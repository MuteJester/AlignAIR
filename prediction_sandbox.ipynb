# %%
import tensorflow as tf
from Trainer import Trainer
from VDeepJModel import VDeepJAllign
import os
from tensorflow.keras.callbacks import ReduceLROnPlateau
# Out:
# 2023-05-28 13:47:48.654702: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# # Create Dataset Objects

# %%
lt = Trainer(
    VDeepJAllign,
    epochs=1,
    batch_size=64,
    verbose=1,
    train_dataset=r"/localdata/alignairr_data/2M_for_training/sim_data_2M_asc_P05_model_s5f_20_rate_001.tsv",
    # pretrained=r"/localdata/alignairr_data/models_2M_version7/saved_models/sim_data_2M_asc_P05_model_s5f_20_rate_001VDeepJModel_0a7db209-595f-4ca1-9b01-bfb54d7eeab6_weights.data-00000-of-00001"
)
# Out:
# 2023-05-28 13:47:53.342767: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-05-28 13:47:53.345299: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-05-28 13:47:54.308678: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: TITAN RTX computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 72 deviceMemorySize: 23.65GiB deviceMemoryBandwidth: 625.94GiB/s
# 2023-05-28 13:47:54.308719: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-05-28 13:47:54.312591: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# ...

# %%
lt.train()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method VDeepJAllign.call of <VDeepJModel.VDeepJAllign object at 0x7fb7938678b0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method VDeepJAllign.call of <VDeepJModel.VDeepJAllign object at 0x7fb7938678b0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...

# %%
lt.save_model("tmp/")
# Out:
# Model Saved!
#  Location: tmp/VDeepJModel_1a58641d-5e85-44cd-9326-25a7a4af5cf9_weights
# 'tmp/VDeepJModel_1a58641d-5e85-44cd-9326-25a7a4af5cf9_weights'

# %%
lt.save_dataset_object("tmp/tmp.ds")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 lt.save_dataset_object("tmp/tmp.ds")
#
# File /home/bcrlab/eisenbr2/AlignAIRR/Trainer.py:226, in Trainer.save_dataset_object(self, path)
#     224 def save_dataset_object(self, path):
#     225     with open(path, "wb") as h:
# --> 226         pickle.dump(self.train_dataset, h)
#     227     print(f"Dataset Object Saved at {path}")
#
# AttributeError: Can't pickle local object 'VDeepJDataset._calculate_sub_classes_map.<locals>.<lambda>'

# %%
lt2 = Trainer(
    VDeepJAllign,
    epochs=1,
    batch_size=64,
    verbose=1,
    train_dataset=r"/localdata/alignairr_data/2M_for_training/sim_data_2M_asc_P05_model_s5f_20_rate_001.tsv",
)

# %%
lt2.rebuild_model()

# %%
lt2.load_model("/localdata/alignairr_data/models_2M_version7/saved_models/sim_data_2M_asc_P05_model_s5f_20_rate_001VDeepJModel_0a7db209-595f-4ca1-9b01-bfb54d7eeab6_weights")

# %%
lt2

# %%
lt2.predict(r"/localdata/alignairr_data/2M_for_training/sim_data_2M_asc_P05_model_s5f_20_rate_001.tsv")
# Out:
# 31250/31250 [==============================] - 359s 11ms/step
# {'v_start': array([[71.071106],
#         [63.532295],
#         [77.83003 ],
#         ...,
#         [71.31791 ],
#         [69.639175],
#         [72.75231 ]], dtype=float32),
#  'v_end': array([[365.53055],
#         [357.68695],
#         [369.83115],
#         ...,
#         [366.2327 ],
#         [366.31403],
#         [371.00195]], dtype=float32),
#  'd_start': array([[373.76596],
#         [370.22528],
#         [377.60205],
#         ...,
#         [378.2581 ],
#         [374.96365],
#         [379.73175]], dtype=float32),
#  'd_end': array([[384.09418],
#         [382.5322 ],
#         [381.63803],
#         ...,
#         [385.30228],
#         [381.72073],
#         [387.4697 ]], dtype=float32),
#  'j_start': array([[393.63025],
#         [395.60522],
#         [388.67328],
#         ...,
#         [391.90814],
#         [391.21228],
#         [392.12885]], dtype=float32),
#  'j_end': array([[440.83978],
# ...

# %%
list_dir = os.listdir("/localdata/alignairr_data/models_2M_version7/saved_models/")

# %%
for file in list_dir:
    if ".data-" in file:
        print(file)
# Out:
# sim_data_2M_asc_P05_model_s5f_20_rate_008VDeepJModel_d086e7fd-14c9-4c50-977f-de0a39cf6544_weights.data-00000-of-00001
# sim_data_2M_asc_P05_model_uniform_rate_008VDeepJModel_020a1168-8166-4e0a-ae8e-ba8c278ac0a1_weights.data-00000-of-00001
# sim_data_2M_asc_P05_model_s5f_20_rate_01VDeepJModel_96303efe-0668-4164-89c9-278c28f1cb18_weights.data-00000-of-00001
# sim_data_2M_asc_P05_model_s5f_20_rate_015VDeepJModel_3c472839-6b0b-4e21-a4e2-0928ac506fea_weights.data-00000-of-00001
# sim_data_2M_asc_P05_model_s5f_20_rate_005VDeepJModel_043192d7-1378-4321-a5b9-c1e36da40d1a_weights.data-00000-of-00001
# sim_data_2M_asc_P05_model_uniform_rate_001VDeepJModel_a8c1484d-5b65-4a34-8ffc-b3c2ab73e084_weights.data-00000-of-00001
# sim_data_2M_asc_P05_model_uniform_rate_005VDeepJModel_f89ed291-e2ca-48d4-9208-31aa3ffd1f20_weights.data-00000-of-00001
# sim_data_2M_asc_P05_model_uniform_rate_01VDeepJModel_30859843-1d35-415e-8e1e-ca47915ae733_weights.data-00000-of-00001
# ...

# %%
import tensorflow as tf
import keras
print(tf.__version__)
print(keras.__version__)
# Out:
# 2023-08-03 18:54:50.149923: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import tensorflow as tf
# ----> 2 import keras
#       3 print(tf.__version__)
#       4 print(keras.__version__)
#
# File ~/anaconda3/envs/vdj_nlp/lib/python3.8/site-packages/keras/__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# ...

# %%
pip install --upgrade keras
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.6 MB/s eta 0:00:0000:0100:010m
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 644.3 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 3.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 5.3 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.0/462.0 kB 5.4 MB/s eta 0:00:0000:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 4.5 MB/s eta 0:00:00:00:0100:01
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4832 sha256=105f9dc2530bd376379784ada1666f8653f373ee1195971b4ee7d4540639ea61
#   Stored in directory: /home/bcrlab/eisenbr2/.cache/pip/wheels/f7/de/e8/f6aec43099b5f725a5227572d0d67a987bc444298b4f14d745
# ...
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp38-cp38-linux_x86_64.whl size=72282 sha256=393c9195a6d93a5ff38d7889a440b84f9dc30da81519d34f8c82b06523e45e7a
# ...
